# %%
import numpy as np
from optimization import *
from fs_plot_utils import *

# %%
np.random.seed(20)
config1 = {"T":0.6,
           "E_init":np.asarray([[0.0],[0.0]]),
           "gamma_vec":np.asarray([[0.4], [0.4]])}

config2 = {"T":0.9,
           "E_init":np.asarray([[0.0],[0.0]]),
           "gamma_vec":np.asarray([[0.4], [0.4]])}
config3 = {"T":0.9,
           "E_init":np.asarray([[0.0],[0.0]]),
           "gamma_vec":np.asarray([[0.7], [0.7]])}
config4 = {"T":0.4,
           "E_init":np.asarray([[0.4],[0.0]]),
           "gamma_vec":np.asarray([[0.7], [0.7]])}

config5 = {"T":0.4,
           "E_init":np.asarray([[0.4],[0.0]]),
           "gamma_vec":np.asarray([[0.4], [0.4]])}

config6 = {"T":0.4,
           "E_init":np.asarray([[0.4],[0.0]]),
           "gamma_vec":np.asarray([[0.3], [0.3]])}

config7 = {"T":0.5,
           "E_init":np.asarray([[0.2],[0.0]]),
           "gamma_vec":np.asarray([[0.3], [0.3]])}

config8 = {"T":0.4,
           "E_init":np.asarray([[0.4],[0.0]]),
           "gamma_vec":np.asarray([[0.4], [0.2]])}

config9 = {"T":0.4,
           "E_init":np.asarray([[0.4],[0.0]]),
           "gamma_vec":np.asarray([[0.2], [0.4]])}

config10 = {"T":0.8,
           "E_init":np.asarray([[0.4],[0.0]]),
           "gamma_vec":np.asarray([[0.2], [0.4]])}

config11 = {"T":0.8,
           "E_init":np.asarray([[0.0],[0.0]]),
           "gamma_vec":np.asarray([[0.2], [0.4]])}

config12 = {"T":0.8,
           "E_init":np.asarray([[0.0],[0.0]]),
           "gamma_vec":np.asarray([[0.1], [0.4]])}

config13 = {"T":0.8,
           "E_init":np.asarray([[0.0],[0.0]]),
           "gamma_vec":np.asarray([[0.4], [0.4]])}



configs  = [config1, config2, config3, config4, config5, config6, config7, config8, config9, config10 ,config11, config12, config13 ]

colinfres = []
randomres = []
uniformres = []
for con in configs:
    _, fsacc = fairSynergy1D(con)
    _, uniacc = uniformAssignment1D(con)
    _, randacc = randomAssignment1D(con)
    colinfres.append(fsacc)
    randomres.append(randacc)
    uniformres.append(uniacc)
    
colinfres = np.asarray(colinfres)
randomres = np.asarray(randomres)
uniformres = np.asarray(uniformres)

# %%
plt.style.use('seaborn-darkgrid')
fig, ax = plt.subplots(figsize=(10, 10))
fig.set_dpi(300)
plot_paired_boxplot(
    df=pd.DataFrame(np.transpose(np.array([randomres, uniformres, colinfres])), columns=['Random\nAllocation','Uniform\nAllocation','FairSynergy']),
    x_var=None,
    y_var=None,
    ylim=None,
    title_str='Cloud Assisted EEN Inference',
    order_list=None,
    pal=sns.color_palette("deep")[::1],
    hue=None,
    ax=ax,
)
for artist in ax.artists:
    artist.set_visible(False)
# Out:
# /tmp/ipykernel_3830521/1170041572.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
